# %%
num_classes = 10

# %%
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# 이미지 하나를 3차원 array 형태로 변환하는 것이 필요 <br>
# 28x28x1

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# %%
x_train = x_train.astype('float32')/255 # 0 ~ 1 사이의 값으로 normalization 하기
x_test = x_test.astype('float32')/255

# %%
from keras.utils import to_categorical 
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1))) # strides = (1,1)

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(128, activation='relu'))

# %%
model.add(Dense(num_classes, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               692352
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# ...
# Total params: 693,962
# Trainable params: 693,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model)
# pip install pydot
# pip install pydotplus
# pip install graphviz

# %%
keras.utils.plot_model(model, show_shapes=True, to_file='cnn_simple.png')

# %%
from tensorflow.keras import optimizers
model.compile(optimizer=optimizers.RMSprop(lr=0.001),
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train_one_hot, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 19s 51ms/step - loss: 0.5237 - accuracy: 0.8159 - val_loss: 0.3673 - val_accuracy: 0.8700
# Epoch 2/10
# 375/375 [==============================] - 18s 49ms/step - loss: 0.3211 - accuracy: 0.8862 - val_loss: 0.3178 - val_accuracy: 0.8829
# Epoch 3/10
# 375/375 [==============================] - 25s 65ms/step - loss: 0.2696 - accuracy: 0.9031 - val_loss: 0.2683 - val_accuracy: 0.9040
# Epoch 4/10
# 375/375 [==============================] - 21s 57ms/step - loss: 0.2360 - accuracy: 0.9142 - val_loss: 0.2665 - val_accuracy: 0.9039
# Epoch 5/10
# 375/375 [==============================] - 22s 59ms/step - loss: 0.2102 - accuracy: 0.9231 - val_loss: 0.2496 - val_accuracy: 0.9128
# Epoch 6/10
# 375/375 [==============================] - 21s 56ms/step - loss: 0.1890 - accuracy: 0.9309 - val_loss: 0.2424 - val_accuracy: 0.9143
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show()

# %%
model.evaluate(x_test, y_test_one_hot)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2744 - accuracy: 0.9109
# [0.27437183260917664, 0.9108999967575073]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_test[0], cmap='gray_r')
plt.show()

# %%
import numpy as np
np.set_printoptions(suppress=True, precision=10)

# %%
prediction = best_model.predict(x_test[0:1]) # 첫번째 이미지 in the test dataset

# %%
prediction
# Out:
# array([[0.0000000249, 0.          , 0.0000000528, 0.          ,
#         0.0000000459, 0.0000037402, 0.0000000402, 0.0000472778,
#         0.0000000444, 0.99994874  ]], dtype=float32)

# %%
y_test[0]
# Out:
# 9

# %%
labels = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(labels[np.argmax(prediction)])
# Out:
# Ankle boot

# %%
model.layers

# %%
conv0 = model.layers[0]

# %%
print(conv0.weights[0].shape, conv0.weights[1].shape)
# Out:
# (3, 3, 1, 32) (32,)

# %%
conv_acti = keras.models.Model(model.input, model.layers[0].output)

# %%
inputs = x_train[0:1]
feature_map = conv_acti.predict(inputs)

# %%
fig, axs = plt.subplots(4,8,figsize=(15,8))
for i in range(4):
    for j in range(8):
        axs[i, j].imshow(feature_map[0, :, :, i*8+j])
        axs[i, j].axis('off')
plt.show()
